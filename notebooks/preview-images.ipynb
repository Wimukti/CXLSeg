# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import skimage.transform as st

# %%
# Preview original image
original_img_filename = '../sample images/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014-original.jpg'
original_img = cv2.imread(original_img_filename, cv2.IMREAD_COLOR)
original_img = cv2.resize(original_img, (224,224))
plt.imshow(original_img)
plt.show()

# %%
# Preview segmented image
segmented_img_filename = '../sample images/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg'
segmented_img = cv2.imread(segmented_img_filename, cv2.IMREAD_COLOR)
plt.imshow(segmented_img)
plt.show()

# %%
# Preview image mask
mask_img_filename = '../sample images/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014-mask.jpg'
mask_img = cv2.imread(mask_img_filename, cv2.IMREAD_COLOR)
plt.imshow(mask_img)
plt.show()
